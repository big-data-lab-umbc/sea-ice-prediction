# %%
import numpy as np
import pandas as pd
from sklearn import datasets, preprocessing
from sklearn.model_selection import train_test_split
import pandas_profiling
from matplotlib import pyplot as plt
import sklearn.gaussian_process as gp
from sklearn.metrics import r2_score
from sklearn.preprocessing import MinMaxScaler, StandardScaler
from sklearn.linear_model import LinearRegression
#from sklearn.gaussian_process import GaussianProcessRegressor
#from sklearn.gaussian_process.kernels import RBF, ConstantKernel as C

# %%
df = pd.read_csv("/content/Arctic_domain_mean_monthly_1979_2021.csv")
# remove date from the set
df = df.drop('Date', 1)
df.loc[:, 'sea_ice_extent_2'] = df['sea_ice_extent']
df
# Out:
#      wind_10m  specific_humidity  ...  sea_ice_extent  sea_ice_extent_2
# 0    5.531398           0.811961  ...        15604191          15604191
# 1    5.328020           0.688896  ...        16378929          16378929
# 2    5.432511           0.916124  ...        16521089          16521089
# 3    4.792836           1.272056  ...        15561238          15561238
# 4    4.819028           2.239776  ...        14085613          14085613
# ..        ...                ...  ...             ...               ...
# 507  5.383687           1.529497  ...        13840000          13840000
# 508  4.777020           2.451088  ...        12660000          12660000
# 509  4.771453           4.176458  ...        10710000          10710000
# 510  4.754014           5.193846  ...         7690000           7690000
# 511  4.635243           5.077386  ...         5750000           5750000
#
# [512 rows x 11 columns]

# %%
#Creating datasets with lag of 1 to 6 months
df1 = df.assign(sea_ice_extent_2 = df.sea_ice_extent_2.shift(-1)).drop(df.index[-1])
df2 = df1.assign(sea_ice_extent_2 = df1.sea_ice_extent_2.shift(-1)).drop(df1.index[-1])
df3 = df2.assign(sea_ice_extent_2 = df2.sea_ice_extent_2.shift(-1)).drop(df2.index[-1])
df4 = df3.assign(sea_ice_extent_2 = df3.sea_ice_extent_2.shift(-1)).drop(df3.index[-1])
df5 = df4.assign(sea_ice_extent_2 = df4.sea_ice_extent_2.shift(-1)).drop(df4.index[-1])
df6 = df5.assign(sea_ice_extent_2 = df5.sea_ice_extent_2.shift(-1)).drop(df5.index[-1])

# %% [markdown]
# ## 1:

# %%
df1
# Out:
#      wind_10m  specific_humidity  ...  sea_ice_extent  sea_ice_extent_2
# 0    5.531398           0.811961  ...        15604191        16378929.0
# 1    5.328020           0.688896  ...        16378929        16521089.0
# 2    5.432511           0.916124  ...        16521089        15561238.0
# 3    4.792836           1.272056  ...        15561238        14085613.0
# 4    4.819028           2.239776  ...        14085613        12653185.0
# ..        ...                ...  ...             ...               ...
# 506  5.494218           1.006108  ...        14640000        13840000.0
# 507  5.383687           1.529497  ...        13840000        12660000.0
# 508  4.777020           2.451088  ...        12660000        10710000.0
# 509  4.771453           4.176458  ...        10710000         7690000.0
# 510  4.754014           5.193846  ...         7690000         5750000.0
#
# [511 rows x 11 columns]

# %%
data = np.array(df1)
target = data[:,-1] #assign last column to be target variable
data = data[:,:-1] #dropping last column from features

# print(data.shape)
# print(target.shape)
LEN_DATA = len(data) #total number of pixels
NUM_TRAIN = LEN_DATA - (24+6) #reserve last 30 months for testing



x_train = data[0:NUM_TRAIN]
y_train = target[0:NUM_TRAIN]

x_test = data[NUM_TRAIN:]
y_test=target[NUM_TRAIN:]

# %%
# x_train, x_test, y_train, y_test = train_test_split(data,target,test_size=0.3,) # .target.reshape(-1, 1)

# %%
print(x_train.shape)
print(y_train.shape)
print(x_test.shape)
print(y_test.shape)
# Out:
# (481, 10)
# (481,)
# (30, 10)
# (30,)

# %%
from sklearn.preprocessing import MinMaxScaler, StandardScaler

scaler_x = MinMaxScaler()
x_train = scaler_x.fit_transform(x_train) 
x_test = scaler_x.transform(x_test) 

scaler_y = MinMaxScaler()
y_train = scaler_y.fit_transform(y_train.reshape(-1,1))
y_test = scaler_y.transform(y_test.reshape(-1,1))

# %%
model = LinearRegression()
model.fit(x_train, y_train)
# Out:
# LinearRegression()

# %%
y_pred = model.predict(x_test)
y_train_pred = model.predict(x_train)

# %%
# %matplotlib inline
#plot 
plt.plot(y_test, color='red')
plt.plot(y_pred)

plt.legend(['y_test','y_pred'])
plt.show()

# %%
# %matplotlib inline
#plot 
plt.plot(y_train, color='red')
plt.plot(y_train_pred)

plt.legend(['y_train','y_train_pred'])
plt.show()

# %%
#Sample code to inverse transform data
#Inverse transformation should be performed after getting predictions
inv_y_train = scaler_y.inverse_transform(y_train)
inv_y_test = scaler_y.inverse_transform(y_test)
inv_y_pred = scaler_y.inverse_transform(y_pred)

# %%
#Save Test data vs predictions
from tempfile import TemporaryFile

#test_data = np.concatenate((inv_y_valid.reshape(-1,1),inv_testPred.reshape(-1,1)), axis=1)
np_file = TemporaryFile()
np.save('MLR_lag1.npy', inv_y_pred)
_ = np_file.seek(0)

# %%
rmse1 = np.sqrt(np.mean((inv_y_pred - inv_y_test) ** 2))
rmse1
# Out:
# 433143.2718494903

# %%
nrmse1 = rmse1/(np.mean(inv_y_test))
nrmse1
# Out:
# 0.04124839984143858

# %%
r2_score1 = r2_score(inv_y_test, inv_y_pred)

# %%
# %matplotlib inline
#plot 
plt.plot(inv_y_test, color='red')
plt.plot(inv_y_pred)

plt.legend(['y_test_inversed','y_test_pred_inveresed'])
plt.show()

# %% [markdown]
# ## 2

# %%
data = np.array(df2)
target = data[:,-1] #assign last column to be target variable
data = data[:,:-1] #dropping last column from features

LEN_DATA = len(data) #total number of pixels
NUM_TRAIN = LEN_DATA - (24+6) #reserve last 30 months for testing

x_train = data[0:NUM_TRAIN]
y_train = target[0:NUM_TRAIN]

x_test = data[NUM_TRAIN:]
y_test=target[NUM_TRAIN:]

# %%
#x_train, x_test, y_train, y_test = train_test_split(data,target,test_size=0.3,)
 
print(x_train.shape)
print(y_train.shape)
print(x_test.shape)
print(y_test.shape)
# Out:
# (480, 10)
# (480,)
# (30, 10)
# (30,)

# %%
from sklearn.preprocessing import MinMaxScaler, StandardScaler
 
scaler_x = MinMaxScaler()
x_train = scaler_x.fit_transform(x_train)
x_test = scaler_x.transform(x_test)
 
scaler_y = MinMaxScaler()
y_train = scaler_y.fit_transform(y_train.reshape(-1,1))
y_test = scaler_y.transform(y_test.reshape(-1,1))

# %%
model = LinearRegression()
model.fit(x_train, y_train)
# Out:
# LinearRegression()

# %%
y_pred = model.predict(x_test)
y_train_pred = model.predict(x_train)

# %%
# %matplotlib inline
#plot
plt.plot(y_test, color='red')
plt.plot(y_pred)
 
plt.legend(['y_test','y_pred'])
plt.show()

# %%
# %matplotlib inline
#plot
plt.plot(y_train, color='red')
plt.plot(y_train_pred)
 
plt.legend(['y_train','y_train_pred'])
plt.show()

# %%
inv_y_train = scaler_y.inverse_transform(y_train)
inv_y_test = scaler_y.inverse_transform(y_test)
inv_y_pred = scaler_y.inverse_transform(y_pred)
# Out:
# [0.92554547]
# [15561238.]

# %%
#Save Test data vs predictions
from tempfile import TemporaryFile

#test_data = np.concatenate((inv_y_valid.reshape(-1,1),inv_testPred.reshape(-1,1)), axis=1)
np_file = TemporaryFile()
np.save('MLR_lag2.npy', inv_y_pred)
_ = np_file.seek(0)

# %%
rmse2 = np.sqrt(np.mean((inv_y_pred - inv_y_test) ** 2))

# %%
nrmse2 = rmse2/(np.mean(inv_y_test))
nrmse2
# Out:
# 0.08502395795629103

# %%
r2_score2 = r2_score(inv_y_test, inv_y_pred)

# %%
# %matplotlib inline
#plot
plt.plot(inv_y_test, color='red')
plt.plot(inv_y_pred)
 
plt.legend(['y_test_inversed','y_test_pred_inveresed'])
plt.show()

# %% [markdown]
# ## 3

# %%
data = np.array(df3)
target = data[:,-1] #assign last column to be target variable
data = data[:,:-1] #dropping last column from features

LEN_DATA = len(data) #total number of pixels
NUM_TRAIN = LEN_DATA - (24+6) #reserve last 30 months for testing

x_train = data[0:NUM_TRAIN]
y_train = target[0:NUM_TRAIN]

x_test = data[NUM_TRAIN:]
y_test=target[NUM_TRAIN:]

# %%
#x_train, x_test, y_train, y_test = train_test_split(data,target,test_size=0.3,)
 
print(x_train.shape)
print(y_train.shape)
print(x_test.shape)
print(y_test.shape)
# Out:
# (479, 10)
# (479,)
# (30, 10)
# (30,)

# %%
from sklearn.preprocessing import MinMaxScaler, StandardScaler
 
scaler_x = MinMaxScaler()
x_train = scaler_x.fit_transform(x_train)
x_test = scaler_x.transform(x_test)
 
scaler_y = MinMaxScaler()
y_train = scaler_y.fit_transform(y_train.reshape(-1,1))
y_test = scaler_y.transform(y_test.reshape(-1,1))

# %%
model = LinearRegression()
model.fit(x_train, y_train)
# Out:
# LinearRegression()

# %%
y_pred = model.predict(x_test)
y_train_pred = model.predict(x_train)

# %%
# %matplotlib inline
#plot
plt.plot(y_test, color='red')
plt.plot(y_pred)
 
plt.legend(['y_test','y_pred'])
plt.show()

# %%
# %matplotlib inline
#plot
plt.plot(y_train, color='red')
plt.plot(y_train_pred)
 
plt.legend(['y_train','y_train_pred'])
plt.show()

# %%
inv_y_train = scaler_y.inverse_transform(y_train)
inv_y_test = scaler_y.inverse_transform(y_test)
inv_y_pred = scaler_y.inverse_transform(y_pred)
 
print(y_train[1]) #print out the scaled value
print(inv_y_train[1]) #print out the inverted/original value
# Out:
# [0.82972163]
# [14085613.]

# %%
#Save Test data vs predictions
from tempfile import TemporaryFile

np_file = TemporaryFile()
np.save('MLR_lag3.npy', inv_y_pred)
_ = np_file.seek(0)

# %%
rmse3 = np.sqrt(np.mean((inv_y_pred - inv_y_test) ** 2))
rmse3
# Out:
# 1429265.5425193375

# %%
nrmse3 = rmse3/(np.mean(inv_y_test))
nrmse3
# Out:
# 0.1361095055815944

# %%
r2_score3 = r2_score(inv_y_test, inv_y_pred)

# %%
# %matplotlib inline
#plot
plt.plot(inv_y_test, color='red')
plt.plot(inv_y_pred)
 
plt.legend(['y_test_inversed','y_test_pred_inveresed'])
plt.show()

# %% [markdown]
# ## 4:

# %%
data = np.array(df4)
target = data[:,-1] #assign last column to be target variable
data = data[:,:-1] #dropping last column from features

LEN_DATA = len(data) #total number of pixels
NUM_TRAIN = LEN_DATA - (24+6) #reserve last 30 months for testing

x_train = data[0:NUM_TRAIN]
y_train = target[0:NUM_TRAIN]

x_test = data[NUM_TRAIN:]
y_test=target[NUM_TRAIN:]

# %%
#x_train, x_test, y_train, y_test = train_test_split(data,target,test_size=0.3,)
 
print(x_train.shape)
print(y_train.shape)
print(x_test.shape)
print(y_test.shape)
# Out:
# (478, 10)
# (478,)
# (30, 10)
# (30,)

# %%
from sklearn.preprocessing import MinMaxScaler, StandardScaler
 
scaler_x = MinMaxScaler()
x_train = scaler_x.fit_transform(x_train)
x_test = scaler_x.transform(x_test)
 
scaler_y = MinMaxScaler()
y_train = scaler_y.fit_transform(y_train.reshape(-1,1))
y_test = scaler_y.transform(y_test.reshape(-1,1))

# %%
model = LinearRegression()
model.fit(x_train, y_train)
# Out:
# LinearRegression()

# %%
y_pred = model.predict(x_test)
y_train_pred = model.predict(x_train)

# %%
# %matplotlib inline
#plot
plt.plot(y_test, color='red')
plt.plot(y_pred)
 
plt.legend(['y_test','y_pred'])
plt.show()

# %%
# %matplotlib inline
#plot
plt.plot(y_train, color='red')
plt.plot(y_train_pred)
 
plt.legend(['y_train','y_train_pred'])
plt.show()

# %%
inv_y_train = scaler_y.inverse_transform(y_train)
inv_y_test = scaler_y.inverse_transform(y_test)
inv_y_pred = scaler_y.inverse_transform(y_pred)

# %%
#Save Test data vs predictions
from tempfile import TemporaryFile

#test_data = np.concatenate((inv_y_valid.reshape(-1,1),inv_testPred.reshape(-1,1)), axis=1)
np_file = TemporaryFile()
np.save('MLR_lag4.npy', inv_y_pred)
_ = np_file.seek(0)

# %%
rmse4 = np.sqrt(np.mean((inv_y_pred - inv_y_test) ** 2))
rmse4
# Out:
# 1714882.5073714103

# %%
nrmse4 = rmse4/(np.mean(inv_y_test))
nrmse4
# Out:
# 0.16330891864741753

# %%
r2_score4 = r2_score(inv_y_test, inv_y_pred)

# %%
# %matplotlib inline
#plot
plt.plot(inv_y_test, color='red')
plt.plot(inv_y_pred)
 
plt.legend(['y_test_inversed','y_test_pred_inveresed'])
plt.show()

# %% [markdown]
# ## 5:

# %%
data = np.array(df5)
target = data[:,-1] #assign last column to be target variable
data = data[:,:-1] #dropping last column from features

LEN_DATA = len(data) #total number of pixels
NUM_TRAIN = LEN_DATA - (24+6) #reserve last 30 months for testing

x_train = data[0:NUM_TRAIN]
y_train = target[0:NUM_TRAIN]

x_test = data[NUM_TRAIN:]
y_test=target[NUM_TRAIN:]

# %%
#x_train, x_test, y_train, y_test = train_test_split(data,target,test_size=0.3,)
 
print(x_train.shape)
print(y_train.shape)
print(x_test.shape)
print(y_test.shape)
# Out:
# (477, 10)
# (477,)
# (30, 10)
# (30,)

# %%
from sklearn.preprocessing import MinMaxScaler, StandardScaler
 
scaler_x = MinMaxScaler()
x_train = scaler_x.fit_transform(x_train)
x_test = scaler_x.transform(x_test)
 
scaler_y = MinMaxScaler()
y_train = scaler_y.fit_transform(y_train.reshape(-1,1))
y_test = scaler_y.transform(y_test.reshape(-1,1))

# %%
model = LinearRegression()
model.fit(x_train, y_train)
# Out:
# LinearRegression()

# %%
y_pred = model.predict(x_test)
y_train_pred = model.predict(x_train)

# %%
# %matplotlib inline
#plot
plt.plot(y_test, color='red')
plt.plot(y_pred)
 
plt.legend(['y_test','y_pred'])
plt.show()

# %%
# %matplotlib inline
#plot
plt.plot(y_train, color='red')
plt.plot(y_train_pred)
 
plt.legend(['y_train','y_train_pred'])
plt.show()

# %%
inv_y_train = scaler_y.inverse_transform(y_train)
inv_y_test = scaler_y.inverse_transform(y_test)
inv_y_pred = scaler_y.inverse_transform(y_pred)
 
print(y_train[1]) #print out the scaled value
print(inv_y_train[1]) #print out the inverted/original value
# Out:
# [0.54689857]
# [10521427.]

# %%
#Save Test data vs predictions
from tempfile import TemporaryFile

#test_data = np.concatenate((inv_y_valid.reshape(-1,1),inv_testPred.reshape(-1,1)), axis=1)
np_file = TemporaryFile()
np.save('MLR_lag5.npy', inv_y_pred)
_ = np_file.seek(0)

# %%
rmse5 = np.sqrt(np.mean((inv_y_pred - inv_y_test) ** 2))
rmse5
# Out:
# 2004225.724213816

# %%
nrmse5 = rmse5/(np.mean(inv_y_test))
nrmse5
# Out:
# 0.1908631841188914

# %%
r2_score5 = r2_score(inv_y_test, inv_y_pred)

# %%
# %matplotlib inline
#plot
plt.plot(inv_y_test, color='red')
plt.plot(inv_y_pred)
 
plt.legend(['y_test_inversed','y_test_pred_inveresed'])
plt.show()

# %% [markdown]
# ## 6:

# %%
data = np.array(df6)
target = data[:,-1] #assign last column to be target variable
data = data[:,:-1] #dropping last column from features

LEN_DATA = len(data) #total number of pixels
NUM_TRAIN = LEN_DATA - (24+6) #reserve last 30 months for testing

x_train = data[0:NUM_TRAIN]
y_train = target[0:NUM_TRAIN]

x_test = data[NUM_TRAIN:]
y_test=target[NUM_TRAIN:]

# %%
#x_train, x_test, y_train, y_test = train_test_split(data,target,test_size=0.3,)
 
print(x_train.shape)
print(y_train.shape)
print(x_test.shape)
print(y_test.shape)
# Out:
# (476, 10)
# (476,)
# (30, 10)
# (30,)

# %%
from sklearn.preprocessing import MinMaxScaler, StandardScaler
 
scaler_x = MinMaxScaler()
x_train = scaler_x.fit_transform(x_train)
x_test = scaler_x.transform(x_test)
 
scaler_y = MinMaxScaler()
y_train = scaler_y.fit_transform(y_train.reshape(-1,1))
y_test = scaler_y.transform(y_test.reshape(-1,1))

# %%
model = LinearRegression()
model.fit(x_train, y_train)
# Out:
# LinearRegression()

# %%
y_pred = model.predict(x_test)
y_train_pred = model.predict(x_train)

# %%
# %matplotlib inline
#plot
plt.plot(y_test, color='red')
plt.plot(y_pred)
 
plt.legend(['y_test','y_pred'])
plt.show()

# %%
# %matplotlib inline
#plot
plt.plot(y_train, color='red')
plt.plot(y_train_pred)
 
plt.legend(['y_train','y_train_pred'])
plt.show()

# %%
inv_y_train = scaler_y.inverse_transform(y_train)
inv_y_test = scaler_y.inverse_transform(y_test)
inv_y_pred = scaler_y.inverse_transform(y_pred)
 
print(y_train[1]) #print out the scaled value
print(inv_y_train[1]) #print out the inverted/original value
# Out:
# [0.36137458]
# [8183421.]

# %%
#Save Test data vs predictions
from tempfile import TemporaryFile

#test_data = np.concatenate((inv_y_valid.reshape(-1,1),inv_testPred.reshape(-1,1)), axis=1)
np_file = TemporaryFile()
np.save('MLR_lag6.npy', inv_y_pred)
_ = np_file.seek(0)

# %%
rmse6 = np.sqrt(np.mean((inv_y_pred - inv_y_test) ** 2))
rmse6
# Out:
# 2166314.544749196

# %%
nrmse6 = rmse6/(np.mean(inv_y_test))
nrmse6
# Out:
# 0.20629896464186295

# %%
r2_score6 = r2_score(inv_y_test, inv_y_pred)

# %%
# %matplotlib inline
#plot
plt.plot(inv_y_test, color='red')
plt.plot(inv_y_pred)
 
plt.legend(['y_test_inversed','y_test_pred_inveresed'])
plt.show()

# %%
print(rmse1, rmse2, rmse3, rmse4, rmse5, rmse6)
# Out:
# 433143.2718494903 892823.8544125061 1429265.5425193375 1714882.5073714103 2004225.724213816 2166314.544749196

# %%
rmse = [rmse1, rmse2, rmse3, rmse4, rmse5, rmse6]
rmse
# Out:
# [433143.2718494903,
#  892823.8544125061,
#  1429265.5425193375,
#  1714882.5073714103,
#  2004225.724213816,
#  2166314.544749196]

# %%
nrmse = [nrmse1, nrmse2, nrmse3, nrmse4, nrmse5, nrmse6]
nrmse
# Out:
# [0.04124839984143858,
#  0.08502395795629103,
#  0.1361095055815944,
#  0.16330891864741753,
#  0.1908631841188914,
#  0.20629896464186295]

# %%
r2 = [r2_score1, r2_score2, r2_score3, r2_score4, r2_score5, r2_score6]
r2
# Out:
# [0.9852645946569139,
#  0.9373919017827168,
#  0.8395555167860974,
#  0.7690235606297073,
#  0.6845052000922132,
#  0.6314113373892776]
